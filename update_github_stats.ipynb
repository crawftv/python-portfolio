# %%
# !pipenv install --pre blackcellmagic
# %load_ext blackcellmagic
# Out:
# Installing blackcellmagic…
# Adding blackcellmagic to Pipfile's [packages]…
# ✔ Installation Succeeded
# Pipfile.lock (ded3df) out of date, updating to (2df67a)…
# Locking [dev-packages] dependencies…
# Locking [packages] dependencies…
# ✔ Success!
# Updated Pipfile.lock (ded3df)!
# Installing dependencies from Pipfile.lock (ded3df)…
#   🐍   ▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉ 118/118 — 00:00:18mmmmmmmmmmmmmmmmmmmmmmmmmmmmmm

# %%
from decouple import config
from firestore_utilities import update_github_events, update_repos,update_repo_files,db
from prefect import task, Flow
from prefect.schedules import CronSchedule
import time

# %%
@task
def nb_update_github_events(db):
    for i in range(25):
        update_github_events(db, i)
        time.sleep(61)


@task
def nb_update_repos(db):
    for i in range(10):
        update_repos(db, i)
        time.sleep(61)


@task
def nb_update_repo_files(db):
    update_repo_files(db)

# %%
with Flow("ETL") as flow:
    nb_update_github_events(db)
    nb_update_repos(db)
    nb_update_repo_files(db)
flow.run()
# Out:
# [2019-08-15 22:09:38,354] INFO - prefect.FlowRunner | Beginning Flow run for 'ETL'
# [2019-08-15 22:09:38,355] INFO - prefect.FlowRunner | Starting flow run.
# [2019-08-15 22:09:38,360] INFO - prefect.TaskRunner | Task 'Constant[Client]': Starting task run...
# [2019-08-15 22:09:38,361] INFO - prefect.TaskRunner | Task 'Constant[Client]': finished task run for task with final state: 'Success'
# [2019-08-15 22:09:38,362] INFO - prefect.TaskRunner | Task 'nb_update_repos': Starting task run...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-d19b1bfc4967> in <module>
#       3     nb_update_repos(db)
#       4     nb_update_repo_files(db)
# ----> 5 flow.run()
#
# ~/.local/share/virtualenvs/python-portfolio-7kLIO7Uz/lib/python3.6/site-packages/prefect/core/flow.py in run(self, parameters, run_on_schedule, runner_cls, **kwargs)
#     997         else:
# ...
